# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if 'module_path' not in sys.path:
    sys.path.append(module_path)

import numpy as np
import nibabel as nib
import neurolang as nl
from typing import AbstractSet, Callable
from neurolang.CD_relations import *
from neurolang.frontend import *
from neurolang.regions import *
from neurolang.region_solver import *
from neurolang.symbols_and_types import TypedSymbolTable

# %matplotlib inline

# %% [markdown]
# ### Load a subject's brain imaging data:

# %%
subject = '100206'
t1w_path = '../data/%s/T1w/T1w_acpc_dc_restore_brain.nii.gz' % subject
labels_path = '../data/%s/T1w/aparc.a2009s+aseg.nii.gz' % subject
labeled_im = nib.load(labels_path)
t1w_im = nib.load(t1w_path)
type(labeled_im)
# Out:
# nibabel.nifti1.Nifti1Image

# %% [markdown]
# ### Basic plotting of the subject data:

# %%
import matplotlib.pyplot as plt
img_data = t1w_im.get_data()

fig = plt.figure(figsize = (20, 20)) 
plt.subplot(1, 3, 1)
plt.imshow(np.rot90(img_data[:,:,100]),cmap = plt.cm.gray,interpolation = 'nearest')
plt.subplot(1, 3, 2)
plt.imshow(np.rot90(img_data[:,100,:]),cmap = plt.cm.gray,interpolation = 'nearest')
plt.subplot(1, 3, 3)
plt.imshow(np.rot90(img_data[100,:,:]),cmap = plt.cm.gray,interpolation = 'nearest')

# %%
from nilearn import plotting
plotting.plot_roi(labeled_im)

# %%
from nilearn.plotting import plot_anat, plot_epi, plot_roi
plot_anat(t1w_im,dim=-1)

# %%
cut_coords = [129, 141, 61]
plot_epi(labeled_im,cut_coords=cut_coords,display_mode='ortho')

# %% [markdown]
# ### Parse regions from subject parcellation:

# %%
from xml.etree import ElementTree
extension_header = ElementTree.fromstring(labeled_im.header.extensions[0].get_content())

labeltable = {
    l.text: int(l.get('Key'))
    for l in extension_header.findall(".//Label")
}
labels = labeled_im.get_data()

# %% [markdown]
# ### Plot a specific region masked over the T1w image:

# %%
brain_stem_voxels = np.transpose((labels == labeltable['BRAIN-STEM']).nonzero())

brain_stem = ExplicitVBR(brain_stem_voxels,t1w_im.affine, t1w_im.shape)
plotting.plot_roi(brain_stem.spatial_image(),t1w_im)

# %% [markdown]
# ### Define a specific region from a coordinate:

# %%
brain_stem_coords = nib.affines.apply_affine(labeled_im.affine, brain_stem_voxels)
center = brain_stem_coords[int(brain_stem_coords.shape[0] / 2)]
radius = 5
sr = SphericalVolume(center, radius)
sphere_voxels = sr.to_ijk(t1w_im.affine)
isinstance(sr, ImplicitVBR)
# Out:
# True

# %% [markdown]
# ### Load labeled regions as symbols into the solver:

# %%
# def region_from_label(solver,label):
#     return get_singleton_element_from_frozenset(solver.symbol_table[label].value)

def define_region_from_parcellation_to_solver(region_name, labeled_im=labeled_im):
    extension_header = ElementTree.fromstring(labeled_im.header.extensions[0].get_content())

    labeltable = {
        l.text: int(l.get('Key'))
        for l in extension_header.findall(".//Label")
    }
    labels = labeled_im.get_data()
    region_voxels = np.transpose((labels == labeltable[region_name]).nonzero())
    region = ExplicitVBR(region_voxels, labeled_im.affine, t1w_im.shape)
    region_solver.symbol_table[nl.Symbol[region_solver.type](region_name)] = nl.Constant[
        AbstractSet[region_solver.type]
    ](frozenset([region]))
    
def get_singleton_element_from_frozenset(fs):
    return next(iter(fs))    

set_type = AbstractSet[Region]
region_solver = RegionsSetSolver(TypedSymbolTable())

# %%
load_parcellation_regions_to_solver(region_solver, labeled_im, 3)
regions = [k.name for k, v in region_solver.symbol_table.symbols_by_type(set_type).items()]
reference_region = regions[0]
len(regions), regions
for region in regions:
    r = region_from_symbol_name(region_solver, region)
    print(r.bounding_box)
    print(r.aabb_tree.height)
# Out:
# AABB(lb=(-27.599997997283936, -35.700001537799835, -6.200001120567322), up=(0.40000152587890625, 2.099997818470001, 18.999998450279236))
# 17
# AABB(lb=(-4.499998390674591, -88.90000063180923, -25.10000079870224), up=(22.10000115633011, -28.700001657009125, 10.599998593330383))
# 18
# AABB(lb=(-55.59999752044678, -66.50000101327896, 12.699998557567596), up=(-43.69999772310257, -53.90000122785568, 39.99999809265137))
# 14

# %% [markdown]
# ### Perform a query over regions:

# %%
#pairs of (relation, region) that return empty set:
#anterior_of CTX_RH_G_AND_S_TRANSV_FRONTOPOL
#superior_of CTX_RH_G_AND_S_PARACENTRAL
#inferior_of BRAIN-STEM
#posterior_of CTX_LH_POLE_OCCIPITAL
#left_of CTX_LH_G_TEMP_SUP-LATERAL
#right_of CTX_RH_G_TEMP_SUP-LATERAL
obtained = query_relation_region(region_solver, 'superior_of', reference_region)
print(len(obtained), obtained)
# Out:
# 1 ['CTX_LH_S_INTERM_PRIM-JENSEN']

# %%
define_region_from_parcellation_to_solver('BRAIN-STEM', labeled_im)
brain_stem = region_from_symbol_name(region_solver, 'BRAIN-STEM')
plotting.plot_roi(brain_stem.spatial_image(),t1w_im)

# %%
define_region_from_parcellation_to_solver('LEFT-INF-LAT-VENT', labeled_im)
vbr = get_singleton_element_from_frozenset(region_solver.symbol_table['LEFT-INF-LAT-VENT'].value)

# %%
import time

def measure_time(func):
    t0 = time.time()
    res = func()
    duration = time.time() - t0
    print('Done in %fs' % duration)
    return res

# %%
define_region_from_parcellation_to_solver('LEFT-CEREBELLUM-CORTEX')
query_relation_region(region_solver, 'overlapping', 'LEFT-CEREBELLUM-CORTEX')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-591cf490798d> in <module>()
#       1 define_region_from_parcellation_to_solver('LEFT-CEREBELLUM-CORTEX')
# ----> 2 query_relation_region(region_solver, 'overlapping', 'LEFT-CEREBELLUM-CORTEX')
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/frontend/util.py in query_relation_region(solver, relation, region, store_symbol_name)
#      39     set_type = AbstractSet[solver.type]
#      40     query = define_query(set_type, relation, region, 'query')
# ---> 41     obtained = solve_query(solver, query, result_symbol_name=store_symbol_name)
#      42     return obtained
#      43
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/frontend/util.py in solve_query(solver, query, result_symbol_name)
#      53
#      54 def solve_query(solver, query, result_symbol_name=None):
# ---> 55     solver.walk(query)
#      56     result = solver.symbol_table[query.symbol.name].value
#      57     obtained = symbol_names_of_region_set_in_solver(solver, result)
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in walk(self, expression)
#      48                 result = tuple(result)
#      49             return result
# ---> 50         return self.match(expression)
#      51
#      52
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_pattern_matching.py in match(self, expression)
#      94             ):
#      95                 logging.debug("**** match {} | {}".format(pattern, guard))
# ---> 96                 return action(self, expression)
#      97         else:
#      98             raise ValueError()
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in query(self, expression)
#      88     @add_match(Query)
#      89     def query(self, expression):
# ---> 90         value = self.walk(expression.value)
#      91         return_type = unify_types(expression.type, value.type)
#      92         value.change_type(return_type)
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in walk(self, expression)
#      48                 result = tuple(result)
#      49             return result
# ---> 50         return self.match(expression)
#      51
#      52
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_pattern_matching.py in match(self, expression)
#      94             ):
#      95                 logging.debug("**** match {} | {}".format(pattern, guard))
# ---> 96                 return action(self, expression)
#      97         else:
#      98             raise ValueError()
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/solver.py in predicate(self, expression)
#      73                 functor = Constant[functor_type](method)
#      74
# ---> 75         return self.walk(functor(expression.args[0]))
#      76
#      77 class SetBasedSolver(GenericSolver):
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in walk(self, expression)
#      48                 result = tuple(result)
#      49             return result
# ---> 50         return self.match(expression)
#      51
#      52
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_pattern_matching.py in match(self, expression)
#      94             ):
#      95                 logging.debug("**** match {} | {}".format(pattern, guard))
# ---> 96                 return action(self, expression)
#      97         else:
#      98             raise ValueError()
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in function(self, expression)
#     214
#     215             result = functor(*new_args, **new_kwargs)
# --> 216             return self.walk(result)
#     217         else:
#     218             return expression
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in walk(self, expression)
#      48                 result = tuple(result)
#      49             return result
# ---> 50         return self.match(expression)
#      51
#      52
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_pattern_matching.py in match(self, expression)
#      94             ):
#      95                 logging.debug("**** match {} | {}".format(pattern, guard))
# ---> 96                 return action(self, expression)
#      97         else:
#      98             raise ValueError()
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/expression_walker.py in evaluate_function(self, expression)
#     166         new_kwargs = {k: v.value for k, v in expression.kwargs.items()}
#     167         result = Constant[result_type](
# --> 168             functor_value(*new_args, **new_kwargs)
#     169         )
#     170         return result
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/region_solver.py in f(reference_region)
#      60     def _define_dir_based_fun(self, direction) -> typing.AbstractSet[Region]:
#      61         def f(reference_region: typing.AbstractSet[Region]) -> typing.AbstractSet[Region]:
# ---> 62             return self.direction(direction, reference_region, refinement_resolution=self.stop_refinement_at)
#      63
#      64         return f
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/region_solver.py in direction(self, direction, reference_regions, refinement_resolution)
#     134                 for region in regions_set:
#     135                     for ref in reference_regions:
# --> 136                         if not cardinal_relation(region, ref, direction, refine_overlapping=True, stop_at=refinement_resolution):
#     137                             break
#     138                     else:
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/CD_relations.py in cardinal_relation(region, reference_region, directions, refine_overlapping, stop_at)
#      20     overlap = is_in_direction(mat, 'O')
#      21     if overlap and refine_overlapping and isinstance(region, ExplicitVBR):
# ---> 22         mat = overlap_resolution(region, reference_region, stop_at)
#      23     return is_in_direction(mat, directions)
#      24
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/CD_relations.py in overlap_resolution(region, reference_region, stop_at)
#      58         mat = direction_matrix(
#      59             [reg.box for reg in current_region_level],
# ---> 60             [reg.box for reg in current_reference_region_level]
#      61         )
#      62         overlap = is_in_direction(mat, 'O')
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/CD_relations.py in direction_matrix(region_bbs, another_region_bbs)
#     105             tensor = rp_vector[0].reshape(1, 3)
#     106             for i in range(1, len(rp_vector)):
# --> 107                 tensor = np.kron(rp_vector[i].reshape((3,) + (1,) * i), tensor)
#     108             res = np.logical_or(res, tensor).astype(int)
#     109     return res
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in kron(a, b)
#     832     axis = nd-1
#     833     for _ in range(nd):
# --> 834         result = concatenate(result, axis=axis)
#     835     wrapper = get_array_prepare(a, b)
#     836     if wrapper is not None:
#
# KeyboardInterrupt:

# %%
define_region_from_parcellation_to_solver('CTX_LH_S_PRECENTRAL-SUP-PART', labeled_im)
define_region_from_parcellation_to_solver('CTX_LH_G_PRECENTRAL', labeled_im)
vbr = get_singleton_element_from_frozenset(region_solver.symbol_table['CTX_LH_S_PRECENTRAL-SUP-PART'].value)
other_vbr = get_singleton_element_from_frozenset(region_solver.symbol_table['CTX_LH_G_PRECENTRAL'].value)

voxels = set(map(tuple, vbr.voxels))
other_voxels = set(map(tuple, other_vbr.voxels))

print(voxels.intersection(other_voxels))
# Out:
# set()

# %%
define_region_from_parcellation_to_solver('BRAIN-STEM', labeled_im)
vbr = get_singleton_element_from_frozenset(region_solver.symbol_table['BRAIN-STEM'].value)
t1w_im.affine

set(map(tuple, vbr.to_ijk(vbr.affine).tolist()))
# Out:
# {(115.0, 155.0, 57.0),
#  (131.0, 116.0, 19.0),
#  (116.0, 147.0, 56.0),
#  (130.0, 130.0, 78.0),
#  (117.0, 122.0, 32.0),
#  (114.0, 164.0, 65.0),
#  (144.0, 146.0, 81.0),
#  (128.0, 147.0, 71.0),
#  (123.0, 149.0, 79.0),
#  (135.0, 130.0, 74.0),
#  (150.0, 153.0, 75.0),
#  (133.0, 119.0, 24.0),
#  (127.0, 156.0, 61.0),
#  (115.0, 124.0, 48.0),
#  (136.0, 141.0, 77.0),
#  (140.0, 132.0, 38.0),
#  (139.0, 129.0, 62.0),
#  (116.0, 125.0, 47.0),
#  (116.0, 150.0, 63.0),
#  (110.0, 130.0, 58.0),
#  (113.0, 148.0, 68.0),
#  (125.0, 137.0, 46.0),
#  (132.0, 151.0, 60.0),
#  (120.0, 139.0, 73.0),
#  (124.0, 138.0, 38.0),
#  (141.0, 143.0, 48.0),
#  (131.0, 146.0, 52.0),
#  (122.0, 143.0, 69.0),
#  (143.0, 141.0, 81.0),
#  (130.0, 146.0, 41.0),
#  (139.0, 138.0, 59.0),
#  (119.0, 154.0, 56.0),
#  (137.0, 126.0, 31.0),
#  (129.0, 151.0, 49.0),
#  (142.0, 145.0, 65.0),
#  (118.0, 157.0, 48.0),
#  (144.0, 148.0, 77.0),
#  (125.0, 142.0, 43.0),
#  (123.0, 126.0, 47.0),
#  (138.0, 134.0, 40.0),
#  (137.0, 141.0, 67.0),
#  (109.0, 135.0, 52.0),
#  (115.0, 126.0, 68.0),
#  (124.0, 141.0, 35.0),
#  (134.0, 123.0, 26.0),
#  (136.0, 131.0, 67.0),
#  (141.0, 148.0, 53.0),
#  (114.0, 152.0, 62.0),
#  (142.0, 158.0, 73.0),
#  (125.0, 125.0, 24.0),
#  (107.0, 148.0, 66.0),
#  (119.0, 159.0, 63.0),
#  (116.0, 144.0, 79.0),
#  (117.0, 125.0, 51.0),
#  (132.0, 117.0, 10.0),
#  (112.0, 135.0, 49.0),
#  (118.0, 152.0, 55.0),
#  (126.0, 124.0, 25.0),
#  (137.0, 160.0, 57.0),
#  (135.0, 129.0, 25.0),
#  (123.0, 123.0, 40.0),
#  (118.0, 142.0, 100.0),
#  (118.0, 124.0, 32.0),
#  (133.0, 161.0, 57.0),
#  (120.0, 129.0, 67.0),
#  (140.0, 137.0, 75.0),
#  (117.0, 136.0, 42.0),
#  (114.0, 159.0, 59.0),
#  (136.0, 144.0, 45.0),
#  (125.0, 144.0, 73.0),
#  (142.0, 139.0, 91.0),
#  (132.0, 136.0, 49.0),
#  (121.0, 149.0, 45.0),
#  (144.0, 154.0, 71.0),
#  (116.0, 133.0, 93.0),
#  (131.0, 141.0, 57.0),
#  (135.0, 138.0, 84.0),
#  (118.0, 123.0, 37.0),
#  (124.0, 143.0, 83.0),
#  (148.0, 158.0, 70.0),
#  (139.0, 135.0, 75.0),
#  (105.0, 150.0, 64.0),
#  (117.0, 141.0, 45.0),
#  (126.0, 147.0, 91.0),
#  (130.0, 151.0, 56.0),
#  (107.0, 150.0, 50.0),
#  (116.0, 142.0, 85.0),
#  (128.0, 148.0, 81.0),
#  (134.0, 156.0, 68.0),
#  (121.0, 146.0, 40.0),
#  (125.0, 131.0, 83.0),
#  (133.0, 131.0, 43.0),
#  (141.0, 122.0, 37.0),
#  (106.0, 153.0, 58.0),
#  (118.0, 158.0, 71.0),
#  (114.0, 129.0, 57.0),
#  (134.0, 118.0, 12.0),
#  (117.0, 152.0, 79.0),
#  (110.0, 153.0, 69.0),
#  (111.0, 157.0, 58.0),
#  (119.0, 144.0, 71.0),
#  (135.0, 117.0, 21.0),
#  (130.0, 154.0, 51.0),
#  (128.0, 121.0, 7.0),
#  (136.0, 146.0, 65.0),
#  (113.0, 135.0, 62.0),
#  (121.0, 165.0, 64.0),
#  (130.0, 136.0, 100.0),
#  (132.0, 138.0, 69.0),
#  (127.0, 138.0, 81.0),
#  (137.0, 118.0, 5.0),
#  (106.0, 156.0, 61.0),
#  (118.0, 133.0, 26.0),
#  (135.0, 132.0, 40.0),
#  (127.0, 127.0, 14.0),
#  (118.0, 139.0, 85.0),
#  (137.0, 133.0, 89.0),
#  (133.0, 164.0, 72.0),
#  (122.0, 144.0, 61.0),
#  (126.0, 131.0, 24.0),
#  (148.0, 148.0, 80.0),
#  (111.0, 150.0, 63.0),
#  (105.0, 148.0, 52.0),
#  (126.0, 145.0, 75.0),
#  (113.0, 140.0, 51.0),
#  (116.0, 136.0, 65.0),
#  (130.0, 143.0, 97.0),
#  (115.0, 128.0, 61.0),
#  (126.0, 116.0, 7.0),
#  (135.0, 137.0, 35.0),
#  (120.0, 147.0, 76.0),
#  (124.0, 130.0, 51.0),
#  (117.0, 146.0, 69.0),
#  (122.0, 151.0, 56.0),
#  (140.0, 145.0, 65.0),
#  (139.0, 130.0, 30.0),
#  (134.0, 139.0, 62.0),
#  (125.0, 152.0, 83.0),
#  (128.0, 145.0, 96.0),
#  (132.0, 128.0, 75.0),
#  (121.0, 141.0, 43.0),
#  (133.0, 134.0, 54.0),
#  (128.0, 131.0, 51.0),
#  (124.0, 133.0, 54.0),
#  (136.0, 139.0, 54.0),
#  (137.0, 139.0, 45.0),
#  (139.0, 143.0, 81.0),
#  (115.0, 158.0, 55.0),
#  (116.0, 134.0, 75.0),
#  (114.0, 161.0, 63.0),
#  (140.0, 165.0, 64.0),
#  (130.0, 141.0, 77.0),
#  (121.0, 138.0, 46.0),
#  (125.0, 139.0, 69.0),
#  (118.0, 134.0, 73.0),
#  (128.0, 142.0, 60.0),
#  (150.0, 146.0, 53.0),
#  (120.0, 137.0, 86.0),
#  (127.0, 155.0, 51.0),
#  (138.0, 147.0, 71.0),
#  (111.0, 155.0, 71.0),
#  (137.0, 128.0, 40.0),
#  (117.0, 144.0, 41.0),
#  (120.0, 123.0, 37.0),
#  (122.0, 149.0, 68.0),
#  (121.0, 121.0, 29.0),
#  (124.0, 122.0, 10.0),
#  (126.0, 156.0, 59.0),
#  (115.0, 155.0, 48.0),
#  (130.0, 130.0, 69.0),
#  (132.0, 130.0, 83.0),
#  (123.0, 149.0, 70.0),
#  (135.0, 130.0, 67.0),
#  (133.0, 119.0, 15.0),
#  (127.0, 156.0, 54.0),
#  (115.0, 124.0, 41.0),
#  (136.0, 141.0, 70.0),
#  (117.0, 149.0, 46.0),
#  (122.0, 136.0, 27.0),
#  (126.0, 155.0, 62.0),
#  (139.0, 129.0, 37.0),
#  (107.0, 142.0, 65.0),
#  (110.0, 130.0, 49.0),
#  (146.0, 156.0, 54.0),
#  (134.0, 148.0, 81.0),
#  (125.0, 137.0, 49.0),
#  (118.0, 136.0, 67.0),
#  (118.0, 126.0, 67.0),
#  (132.0, 151.0, 69.0),
#  (109.0, 130.0, 48.0),
#  (120.0, 139.0, 70.0),
#  (124.0, 138.0, 41.0),
#  (141.0, 143.0, 71.0),
#  (131.0, 146.0, 61.0),
#  (122.0, 143.0, 94.0),
#  (143.0, 141.0, 88.0),
#  (142.0, 145.0, 78.0),
#  (121.0, 151.0, 64.0),
#  (133.0, 128.0, 69.0),
#  (138.0, 122.0, 42.0),
#  (118.0, 157.0, 57.0),
#  (132.0, 152.0, 77.0),
#  (144.0, 148.0, 68.0),
#  (125.0, 142.0, 52.0),
#  (130.0, 122.0, 17.0),
#  (106.0, 146.0, 83.0),
#  (128.0, 139.0, 37.0),
#  (138.0, 134.0, 63.0),
#  (109.0, 135.0, 59.0),
#  (124.0, 141.0, 44.0),
#  (136.0, 131.0, 72.0),
#  (137.0, 131.0, 39.0),
#  (105.0, 156.0, 67.0),
#  (108.0, 132.0, 51.0),
#  (142.0, 158.0, 64.0),
#  (117.0, 125.0, 42.0),
#  (132.0, 117.0, 19.0),
#  (118.0, 152.0, 62.0),
#  (126.0, 124.0, 16.0),
#  (132.0, 135.0, 102.0),
#  (123.0, 123.0, 19.0),
#  (138.0, 157.0, 58.0),
#  (118.0, 124.0, 43.0),
#  (120.0, 129.0, 76.0),
#  (119.0, 120.0, 23.0),
#  (127.0, 147.0, 41.0),
#  (117.0, 136.0, 35.0),
#  (122.0, 141.0, 78.0),
#  (125.0, 144.0, 62.0),
#  (116.0, 139.0, 43.0),
#  (142.0, 139.0, 84.0),
#  (132.0, 136.0, 40.0),
#  (121.0, 149.0, 84.0),
#  (133.0, 142.0, 89.0),
#  (128.0, 155.0, 70.0),
#  (131.0, 141.0, 48.0),
#  (135.0, 138.0, 93.0),
#  (120.0, 150.0, 44.0),
#  (118.0, 123.0, 46.0),
#  (127.0, 148.0, 44.0),
#  (124.0, 143.0, 88.0),
#  (136.0, 133.0, 92.0),
#  (139.0, 135.0, 66.0),
#  (117.0, 141.0, 36.0),
#  (130.0, 151.0, 49.0),
#  (139.0, 137.0, 47.0),
#  (107.0, 150.0, 75.0),
#  (116.0, 142.0, 44.0),
#  (128.0, 148.0, 72.0),
#  (130.0, 133.0, 96.0),
#  (113.0, 156.0, 71.0),
#  (129.0, 146.0, 57.0),
#  (128.0, 134.0, 25.0),
#  (120.0, 145.0, 41.0),
#  (114.0, 129.0, 46.0),
#  (134.0, 118.0, 27.0),
#  (141.0, 137.0, 96.0),
#  (117.0, 152.0, 68.0),
#  (139.0, 124.0, 30.0),
#  (110.0, 153.0, 50.0),
#  (141.0, 151.0, 49.0),
#  (122.0, 135.0, 68.0),
#  (135.0, 117.0, 28.0),
#  (130.0, 154.0, 58.0),
#  (132.0, 120.0, 11.0),
#  (136.0, 146.0, 72.0),
#  (113.0, 135.0, 53.0),
#  (119.0, 130.0, 43.0),
#  (143.0, 163.0, 69.0),
#  (137.0, 118.0, 14.0),
#  (121.0, 143.0, 74.0),
#  (127.0, 138.0, 70.0),
#  (133.0, 152.0, 79.0),
#  (112.0, 132.0, 61.0),
#  (142.0, 137.0, 64.0),
#  (128.0, 129.0, 92.0),
#  (133.0, 127.0, 12.0),
#  (135.0, 132.0, 33.0),
#  (127.0, 127.0, 25.0),
#  (118.0, 139.0, 94.0),
#  (137.0, 133.0, 64.0),
#  (142.0, 161.0, 60.0),
#  (109.0, 143.0, 85.0),
#  (119.0, 127.0, 32.0),
#  (136.0, 155.0, 66.0),
#  (141.0, 156.0, 52.0),
#  (145.0, 150.0, 72.0),
#  (105.0, 148.0, 61.0),
#  (126.0, 145.0, 80.0),
#  (113.0, 140.0, 56.0),
#  (107.0, 156.0, 65.0),
#  (119.0, 135.0, 44.0),
#  (104.0, 151.0, 53.0),
#  (116.0, 136.0, 88.0),
#  (132.0, 141.0, 57.0),
#  (112.0, 143.0, 48.0),
#  (126.0, 116.0, 14.0),
#  (135.0, 137.0, 42.0),
#  (117.0, 146.0, 78.0),
#  (110.0, 159.0, 74.0),
#  (105.0, 145.0, 58.0),
#  (117.0, 128.0, 29.0),
#  (119.0, 146.0, 76.0),
#  (130.0, 152.0, 66.0),
#  (134.0, 139.0, 39.0),
#  (132.0, 128.0, 50.0),
#  (121.0, 141.0, 34.0),
#  (133.0, 134.0, 63.0),
#  (144.0, 162.0, 68.0),
#  (128.0, 131.0, 72.0),
#  (120.0, 142.0, 42.0),
#  (136.0, 139.0, 47.0),
#  (137.0, 139.0, 84.0),
#  (148.0, 150.0, 71.0),
#  (128.0, 116.0, 22.0),
#  (139.0, 143.0, 88.0),
#  (134.0, 150.0, 60.0),
#  (129.0, 148.0, 80.0),
#  (125.0, 145.0, 97.0),
#  (116.0, 134.0, 82.0),
#  (129.0, 115.0, 15.0),
#  (121.0, 138.0, 39.0),
#  (125.0, 139.0, 76.0),
#  (127.0, 137.0, 29.0),
#  (130.0, 141.0, 90.0),
#  (118.0, 134.0, 64.0),
#  (134.0, 164.0, 69.0),
#  (120.0, 137.0, 47.0),
#  (127.0, 155.0, 74.0),
#  (138.0, 147.0, 72.0),
#  (129.0, 162.0, 75.0),
#  (117.0, 144.0, 94.0),
#  (122.0, 149.0, 77.0),
#  (110.0, 145.0, 68.0),
#  (121.0, 121.0, 20.0),
#  (126.0, 156.0, 50.0),
#  (119.0, 152.0, 70.0),
#  (130.0, 130.0, 92.0),
#  (121.0, 157.0, 65.0),
#  (132.0, 130.0, 90.0),
#  (128.0, 137.0, 66.0),
#  (133.0, 119.0, 6.0),
#  (123.0, 135.0, 42.0),
#  (115.0, 124.0, 34.0),
#  (135.0, 140.0, 55.0),
#  (109.0, 151.0, 79.0),
#  (126.0, 155.0, 55.0),
#  (139.0, 129.0, 44.0),
#  (113.0, 148.0, 82.0),
#  (116.0, 128.0, 66.0),
#  (132.0, 133.0, 31.0),
#  (131.0, 142.0, 88.0),
#  (125.0, 137.0, 56.0),
#  (118.0, 136.0, 74.0),
#  (118.0, 126.0, 74.0),
#  (132.0, 151.0, 82.0),
#  (123.0, 128.0, 47.0),
#  (127.0, 145.0, 68.0),
#  (120.0, 139.0, 95.0),
#  (124.0, 138.0, 48.0),
#  (131.0, 128.0, 23.0),
#  (135.0, 145.0, 44.0),
#  (136.0, 136.0, 52.0),
#  (117.0, 138.0, 68.0),
#  (122.0, 143.0, 87.0),
#  (141.0, 143.0, 94.0),
#  (108.0, 129.0, 49.0),
#  (110.0, 151.0, 80.0),
#  (140.0, 153.0, 64.0),
#  (103.0, 149.0, 85.0),
#  (134.0, 147.0, 45.0),
#  (121.0, 151.0, 79.0),
#  (133.0, 128.0, 74.0),
#  (137.0, 126.0, 41.0),
#  (138.0, 122.0, 33.0),
#  (114.0, 162.0, 67.0),
#  (132.0, 152.0, 68.0),
#  (144.0, 148.0, 83.0),
#  (121.0, 133.0, 24.0),
#  (119.0, 162.0, 58.0),
#  (123.0, 151.0, 73.0),
#  (125.0, 142.0, 61.0),
#  (106.0, 146.0, 90.0),
#  (128.0, 139.0, 50.0),
#  (130.0, 122.0, 24.0),
#  (138.0, 134.0, 54.0),
#  (124.0, 141.0, 53.0),
#  (141.0, 134.0, 72.0),
#  (136.0, 131.0, 49.0),
#  (137.0, 131.0, 62.0),
#  (108.0, 132.0, 58.0),
#  (142.0, 158.0, 63.0),
#  (125.0, 125.0, 10.0),
#  (115.0, 150.0, 54.0),
#  (137.0, 123.0, 34.0),
#  (117.0, 125.0, 37.0),
#  (132.0, 117.0, 28.0),
#  (113.0, 138.0, 90.0),
#  (129.0, 123.0, 9.0),
#  (133.0, 124.0, 44.0),
#  (123.0, 123.0, 26.0),
#  (138.0, 157.0, 51.0),
#  (120.0, 129.0, 85.0),
#  (115.0, 123.0, 53.0),
#  (119.0, 120.0, 24.0),
#  (127.0, 147.0, 48.0),
#  (111.0, 147.0, 68.0),
#  (137.0, 152.0, 59.0),
#  (148.0, 151.0, 81.0),
#  (117.0, 136.0, 56.0),
#  (122.0, 141.0, 71.0),
#  (125.0, 144.0, 55.0),
#  (115.0, 147.0, 49.0),
#  (119.0, 128.0, 76.0),
#  (130.0, 138.0, 70.0),
#  (132.0, 136.0, 39.0),
#  (133.0, 142.0, 82.0),
#  (124.0, 147.0, 63.0),
#  (123.0, 157.0, 71.0),
#  (131.0, 141.0, 47.0),
#  (135.0, 138.0, 66.0),
#  (118.0, 123.0, 23.0),
#  (127.0, 148.0, 53.0),
#  (136.0, 133.0, 69.0),
#  (140.0, 140.0, 62.0),
#  (105.0, 150.0, 82.0),
#  (109.0, 159.0, 73.0),
#  (117.0, 141.0, 63.0),
#  (126.0, 147.0, 45.0),
#  (107.0, 150.0, 64.0),
#  (128.0, 148.0, 71.0),
#  (113.0, 156.0, 76.0),
#  (129.0, 146.0, 50.0),
#  (133.0, 131.0, 25.0),
#  (114.0, 129.0, 39.0),
#  (134.0, 118.0, 18.0),
#  (109.0, 138.0, 55.0),
#  (120.0, 131.0, 65.0),
#  (136.0, 128.0, 30.0),
#  (136.0, 121.0, 0.0),
#  (139.0, 124.0, 39.0),
#  (140.0, 120.0, 43.0),
#  (122.0, 135.0, 77.0),
#  (140.0, 151.0, 59.0),
#  (141.0, 151.0, 56.0),
#  (136.0, 146.0, 83.0),
#  (132.0, 120.0, 2.0),
#  (151.0, 147.0, 85.0),
#  (119.0, 130.0, 32.0),
#  (137.0, 118.0, 23.0),
#  (121.0, 143.0, 65.0),
#  (127.0, 138.0, 63.0),
#  (129.0, 159.0, 57.0),
#  (112.0, 132.0, 52.0),
#  (118.0, 133.0, 40.0),
#  (128.0, 129.0, 85.0),
#  (133.0, 127.0, 19.0),
#  (133.0, 152.0, 68.0),
#  (135.0, 132.0, 90.0),
#  (127.0, 127.0, 16.0),
#  (144.0, 156.0, 69.0),
#  (137.0, 133.0, 75.0),
#  (139.0, 121.0, 28.0),
#  (119.0, 127.0, 43.0),
#  (122.0, 144.0, 47.0),
#  (111.0, 150.0, 45.0),
#  (141.0, 156.0, 61.0),
#  (145.0, 150.0, 65.0),
#  (131.0, 121.0, 3.0),
#  (126.0, 145.0, 89.0),
#  (135.0, 126.0, 38.0),
#  (142.0, 150.0, 65.0),
#  (107.0, 156.0, 74.0),
#  (119.0, 135.0, 39.0),
#  (104.0, 151.0, 58.0),
#  (116.0, 136.0, 87.0),
#  (132.0, 141.0, 50.0),
#  (125.0, 129.0, 85.0),
#  (112.0, 143.0, 57.0),
#  (118.0, 128.0, 47.0),
#  (126.0, 116.0, 17.0),
#  (131.0, 136.0, 58.0),
#  (122.0, 151.0, 42.0),
#  (110.0, 159.0, 67.0),
#  (128.0, 160.0, 56.0),
#  (131.0, 160.0, 70.0),
#  (117.0, 128.0, 34.0),
#  (119.0, 146.0, 69.0),
#  (140.0, 145.0, 83.0),
#  (125.0, 152.0, 65.0),
#  (152.0, 146.0, 84.0),
#  (132.0, 128.0, 57.0),
#  (121.0, 141.0, 53.0),
#  (133.0, 134.0, 40.0),
#  (128.0, 131.0, 65.0),
#  (123.0, 133.0, 73.0),
#  (127.0, 146.0, 100.0),
#  (120.0, 142.0, 61.0),
#  (114.0, 130.0, 60.0),
#  (124.0, 133.0, 24.0),
#  (131.0, 133.0, 49.0),
#  (135.0, 146.0, 76.0),
#  (136.0, 139.0, 36.0),
#  (137.0, 139.0, 91.0),
#  (109.0, 141.0, 64.0),
#  (148.0, 150.0, 78.0),
#  (128.0, 116.0, 13.0),
#  (139.0, 143.0, 67.0),
#  (117.0, 133.0, 37.0),
#  (145.0, 148.0, 53.0),
#  (142.0, 148.0, 85.0),
#  (129.0, 148.0, 73.0),
#  (107.0, 158.0, 58.0),
#  (116.0, 134.0, 93.0),
#  (144.0, 151.0, 61.0),
#  (130.0, 141.0, 99.0),
#  (121.0, 138.0, 48.0),
#  (133.0, 155.0, 51.0),
#  (138.0, 119.0, 6.0),
#  (118.0, 134.0, 95.0),
#  (120.0, 137.0, 56.0),
#  (114.0, 137.0, 49.0),
#  (148.0, 159.0, 68.0),
#  (138.0, 147.0, 81.0),
#  (129.0, 162.0, 68.0),
#  (137.0, 128.0, 30.0),
#  (142.0, 162.0, 74.0),
#  (117.0, 144.0, 71.0),
#  (110.0, 145.0, 77.0),
#  (121.0, 121.0, 15.0),
#  (119.0, 152.0, 79.0),
#  (145.0, 145.0, 50.0),
#  (130.0, 130.0, 43.0),
#  (113.0, 143.0, 54.0),
#  (107.0, 155.0, 61.0),
#  (144.0, 146.0, 58.0),
#  (128.0, 147.0, 98.0),
#  (127.0, 130.0, 89.0),
#  (132.0, 130.0, 77.0),
#  (106.0, 148.0, 53.0),
#  (126.0, 163.0, 68.0),
#  (128.0, 137.0, 75.0),
#  (123.0, 135.0, 61.0),
#  (127.0, 119.0, 6.0),
#  (137.0, 157.0, 65.0),
#  (109.0, 151.0, 86.0),
#  (122.0, 136.0, 37.0),
#  (142.0, 142.0, 75.0),
#  (113.0, 148.0, 43.0),
#  (131.0, 142.0, 81.0),
#  (125.0, 137.0, 67.0),
#  (127.0, 139.0, 96.0),
#  (118.0, 136.0, 85.0),
#  (123.0, 128.0, 56.0),
#  (127.0, 145.0, 83.0),
#  (120.0, 139.0, 84.0),
#  (124.0, 138.0, 59.0),
#  (135.0, 145.0, 59.0),
#  (136.0, 136.0, 59.0),
#  (141.0, 143.0, 85.0),
#  (117.0, 138.0, 93.0),
#  (140.0, 153.0, 73.0),
#  (137.0, 126.0, 34.0),
#  (138.0, 122.0, 56.0),
#  (121.0, 133.0, 35.0),
#  (123.0, 151.0, 64.0),
#  (127.0, 140.0, 101.0),
#  (130.0, 122.0, 7.0),
#  (128.0, 139.0, 59.0),
#  (137.0, 141.0, 100.0),
#  (141.0, 134.0, 65.0),
#  (120.0, 134.0, 27.0),
#  (124.0, 141.0, 62.0),
#  (136.0, 131.0, 62.0),
#  (136.0, 124.0, 40.0),
#  (137.0, 131.0, 53.0),
#  (142.0, 158.0, 54.0),
#  (128.0, 124.0, 23.0),
#  (132.0, 123.0, 42.0),
#  (139.0, 151.0, 73.0),
#  (115.0, 150.0, 63.0),
#  (137.0, 123.0, 41.0),
#  (141.0, 163.0, 62.0),
#  (142.0, 140.0, 99.0),
#  (113.0, 138.0, 67.0),
#  (133.0, 124.0, 37.0),
#  (121.0, 130.0, 38.0),
#  (118.0, 142.0, 65.0),
#  (137.0, 138.0, 97.0),
#  (149.0, 153.0, 68.0),
#  (127.0, 147.0, 59.0),
#  (115.0, 123.0, 44.0),
#  (111.0, 147.0, 79.0),
#  (137.0, 152.0, 48.0),
#  (117.0, 136.0, 49.0),
#  (122.0, 141.0, 92.0),
#  (126.0, 148.0, 51.0),
#  (125.0, 144.0, 44.0),
#  (115.0, 147.0, 56.0),
#  (119.0, 128.0, 69.0),
#  (116.0, 139.0, 57.0),
#  (130.0, 138.0, 77.0),
#  (132.0, 136.0, 30.0),
#  (146.0, 161.0, 73.0),
#  (121.0, 149.0, 70.0),
#  (124.0, 147.0, 52.0),
#  (133.0, 142.0, 75.0),
#  (132.0, 154.0, 75.0),
#  (131.0, 141.0, 38.0),
#  (135.0, 138.0, 75.0),
#  (127.0, 148.0, 62.0),
#  (136.0, 133.0, 78.0),
#  (140.0, 140.0, 53.0),
#  (109.0, 159.0, 64.0),
#  (117.0, 141.0, 54.0),
#  (122.0, 128.0, 19.0),
#  (126.0, 147.0, 54.0),
#  (142.0, 156.0, 70.0),
#  (121.0, 156.0, 76.0),
#  (139.0, 137.0, 61.0),
#  (116.0, 142.0, 62.0),
#  (128.0, 148.0, 62.0),
#  (129.0, 146.0, 43.0),
#  (138.0, 127.0, 41.0),
#  (109.0, 138.0, 56.0),
#  (120.0, 131.0, 78.0),
#  (136.0, 128.0, 21.0),
#  (136.0, 121.0, 25.0),
#  (139.0, 124.0, 40.0),
#  (140.0, 151.0, 48.0),
#  (122.0, 135.0, 86.0),
#  (141.0, 151.0, 79.0),
#  (132.0, 120.0, 25.0),
#  (139.0, 146.0, 56.0),
#  (119.0, 130.0, 57.0),
#  (137.0, 118.0, 24.0),
#  (121.0, 143.0, 88.0),
#  (127.0, 138.0, 52.0),
#  (118.0, 133.0, 33.0),
#  (132.0, 144.0, 69.0),
#  (133.0, 127.0, 26.0),
#  (144.0, 156.0, 76.0),
#  (135.0, 132.0, 83.0),
#  (126.0, 141.0, 60.0),
#  (134.0, 125.0, 36.0),
#  (138.0, 158.0, 55.0),
#  (141.0, 142.0, 87.0),
#  (124.0, 117.0, 20.0),
#  (115.0, 156.0, 74.0),
#  (105.0, 148.0, 75.0),
#  (131.0, 121.0, 10.0),
#  (135.0, 126.0, 47.0),
#  (142.0, 150.0, 72.0),
#  (125.0, 147.0, 59.0),
#  (119.0, 135.0, 62.0),
#  (128.0, 150.0, 78.0),
#  (123.0, 150.0, 84.0),
#  (113.0, 146.0, 73.0),
#  (112.0, 143.0, 46.0),
#  (118.0, 128.0, 38.0),
#  (128.0, 140.0, 101.0),
#  (132.0, 141.0, 43.0),
#  (131.0, 136.0, 51.0),
#  (138.0, 149.0, 50.0),
#  (111.0, 139.0, 69.0),
#  (117.0, 128.0, 43.0),
#  (122.0, 133.0, 70.0),
#  (125.0, 152.0, 54.0),
#  (133.0, 136.0, 30.0),
#  (116.0, 131.0, 35.0),
#  (132.0, 128.0, 32.0),
#  (121.0, 141.0, 76.0),
#  (133.0, 134.0, 81.0),
#  (123.0, 133.0, 64.0),
#  (131.0, 133.0, 56.0),
#  (120.0, 142.0, 52.0),
#  (114.0, 130.0, 43.0),
#  (135.0, 146.0, 69.0),
#  (137.0, 139.0, 66.0),
#  (110.0, 154.0, 63.0),
#  (128.0, 116.0, 4.0),
#  (136.0, 157.0, 68.0),
#  (117.0, 133.0, 44.0),
#  (139.0, 143.0, 74.0),
#  (140.0, 125.0, 31.0),
#  (140.0, 148.0, 47.0),
#  (130.0, 159.0, 57.0),
#  (121.0, 148.0, 86.0),
#  (133.0, 141.0, 89.0),
#  (145.0, 148.0, 74.0),
#  (107.0, 158.0, 67.0),
#  (116.0, 134.0, 36.0),
#  (128.0, 156.0, 64.0),
#  (144.0, 151.0, 50.0),
#  (125.0, 139.0, 98.0),
#  (129.0, 154.0, 49.0),
#  (106.0, 145.0, 59.0),
#  (118.0, 134.0, 86.0),
#  (120.0, 137.0, 49.0),
#  (134.0, 126.0, 19.0),
#  (142.0, 162.0, 65.0),
#  (117.0, 144.0, 76.0),
#  (110.0, 145.0, 58.0),
#  (111.0, 149.0, 57.0),
#  (130.0, 130.0, 34.0),
#  (113.0, 143.0, 61.0),
#  (119.0, 138.0, 35.0),
#  (144.0, 146.0, 53.0),
#  (121.0, 135.0, 66.0),
#  (129.0, 135.0, 42.0),
#  (133.0, 144.0, 71.0),
#  (112.0, 140.0, 53.0),
#  (106.0, 148.0, 60.0),
#  (128.0, 137.0, 84.0),
#  (144.0, 164.0, 70.0),
#  (123.0, 135.0, 52.0),
#  (127.0, 119.0, 17.0),
#  (135.0, 140.0, 41.0),
#  (122.0, 136.0, 60.0),
#  (136.0, 147.0, 74.0),
#  (111.0, 142.0, 60.0),
#  (115.0, 148.0, 80.0),
#  (145.0, 158.0, 64.0),
#  (142.0, 142.0, 66.0),
#  (132.0, 133.0, 49.0),
#  (131.0, 142.0, 70.0),
#  (125.0, 137.0, 74.0),
#  (135.0, 135.0, 97.0),
#  (118.0, 136.0, 92.0),
#  (123.0, 128.0, 49.0),
#  (127.0, 145.0, 90.0),
#  (135.0, 145.0, 50.0),
#  (136.0, 136.0, 34.0),
#  (148.0, 153.0, 73.0),
#  (129.0, 160.0, 73.0),
#  (117.0, 138.0, 86.0),
#  (122.0, 143.0, 57.0),
#  (110.0, 151.0, 66.0),
#  (151.0, 149.0, 58.0),
#  (119.0, 154.0, 68.0),
#  (130.0, 128.0, 90.0),
#  (134.0, 147.0, 63.0),
#  (137.0, 126.0, 59.0),
#  (138.0, 122.0, 55.0),
#  (121.0, 133.0, 42.0),
#  (130.0, 122.0, 14.0),
#  (128.0, 139.0, 64.0),
#  (141.0, 134.0, 58.0),
#  (105.0, 142.0, 59.0),
#  (120.0, 134.0, 34.0),
#  (136.0, 131.0, 39.0),
#  (136.0, 124.0, 39.0),
#  (137.0, 131.0, 76.0),
#  (109.0, 149.0, 65.0),
#  (135.0, 118.0, 2.0),
#  (128.0, 124.0, 30.0),
#  (132.0, 123.0, 35.0),
#  (139.0, 151.0, 64.0),
#  (130.0, 135.0, 31.0),
#  (121.0, 140.0, 96.0),
#  (134.0, 158.0, 52.0),
#  (113.0, 138.0, 76.0),
#  (137.0, 123.0, 48.0),
#  (138.0, 165.0, 69.0),
#  (128.0, 132.0, 74.0),
#  (129.0, 123.0, 23.0),
#  (121.0, 130.0, 47.0),
#  (127.0, 129.0, 21.0),
#  (123.0, 123.0, 12.0),
#  (133.0, 124.0, 50.0),
#  (118.0, 142.0, 72.0),
#  (133.0, 147.0, 44.0),
#  (137.0, 138.0, 90.0),
#  (120.0, 129.0, 39.0),
#  (115.0, 123.0, 39.0),
#  (127.0, 147.0, 66.0),
#  (148.0, 151.0, 71.0),
#  (117.0, 136.0, 70.0),
#  (122.0, 141.0, 85.0),
#  (126.0, 148.0, 58.0),
#  (131.0, 122.0, 34.0),
#  (130.0, 138.0, 84.0),
#  (134.0, 165.0, 73.0),
#  (117.0, 160.0, 58.0),
#  (121.0, 149.0, 73.0),
#  (124.0, 147.0, 45.0),
#  (133.0, 142.0, 68.0),
#  (132.0, 154.0, 66.0),
#  (127.0, 154.0, 72.0),
#  (140.0, 130.0, 31.0),
#  (135.0, 148.0, 47.0),
#  (137.0, 149.0, 70.0),
#  (122.0, 128.0, 26.0),
#  (126.0, 147.0, 63.0),
#  (121.0, 156.0, 69.0),
#  (139.0, 137.0, 52.0),
#  (128.0, 148.0, 53.0),
#  (123.0, 160.0, 59.0),
#  (138.0, 127.0, 34.0),
#  (131.0, 134.0, 80.0),
#  (143.0, 153.0, 61.0),
#  (119.0, 161.0, 63.0),
#  (134.0, 118.0, 32.0),
#  (123.0, 136.0, 39.0),
#  (120.0, 131.0, 87.0),
#  (139.0, 124.0, 49.0),
#  (136.0, 128.0, 44.0),
#  (136.0, 121.0, 18.0),
#  (111.0, 157.0, 70.0),
#  (105.0, 147.0, 87.0),
#  (117.0, 130.0, 76.0),
#  (119.0, 144.0, 99.0),
#  (108.0, 137.0, 57.0),
#  (110.0, 143.0, 72.0),
#  (122.0, 135.0, 95.0),
#  (132.0, 120.0, 16.0),
#  (139.0, 146.0, 49.0),
#  (119.0, 130.0, 78.0),
#  (142.0, 155.0, 60.0),
#  (130.0, 136.0, 64.0),
#  (121.0, 143.0, 87.0),
#  (127.0, 138.0, 45.0),
#  (137.0, 118.0, 33.0),
#  (118.0, 133.0, 54.0),
#  (132.0, 144.0, 76.0),
#  (133.0, 127.0, 33.0),
#  (136.0, 163.0, 61.0),
#  (123.0, 159.0, 65.0),
#  (126.0, 141.0, 53.0),
#  (134.0, 125.0, 45.0),
#  (135.0, 132.0, 76.0),
#  (138.0, 158.0, 62.0),
#  (141.0, 142.0, 64.0),
#  (109.0, 143.0, 58.0),
#  (113.0, 164.0, 75.0),
#  (124.0, 117.0, 13.0),
#  (137.0, 155.0, 54.0),
#  (115.0, 156.0, 67.0),
#  (105.0, 148.0, 80.0),
#  (131.0, 121.0, 17.0),
#  (135.0, 126.0, 52.0),
#  (142.0, 150.0, 55.0),
#  (125.0, 147.0, 50.0),
#  (115.0, 142.0, 46.0),
#  (122.0, 127.0, 29.0),
#  (128.0, 150.0, 65.0),
#  (123.0, 150.0, 77.0),
#  (113.0, 146.0, 66.0),
#  (124.0, 144.0, 58.0),
#  (118.0, 128.0, 49.0),
#  (132.0, 141.0, 36.0),
#  (131.0, 136.0, 44.0),
#  (138.0, 149.0, 59.0),
#  (137.0, 144.0, 51.0),
#  (131.0, 160.0, 56.0),
#  (117.0, 128.0, 48.0),
#  (122.0, 133.0, 79.0),
#  (125.0, 152.0, 63.0),
#  (119.0, 136.0, 68.0),
#  (116.0, 131.0, 40.0),
#  (132.0, 128.0, 47.0),
#  (121.0, 141.0, 71.0),
#  (124.0, 155.0, 55.0),
#  (133.0, 134.0, 90.0),
#  (128.0, 131.0, 87.0),
#  (123.0, 133.0, 95.0),
#  (131.0, 133.0, 39.0),
#  (137.0, 139.0, 73.0),
#  (140.0, 148.0, 54.0),
#  (140.0, 125.0, 40.0),
#  (117.0, 133.0, 55.0),
#  (145.0, 148.0, 67.0),
#  (142.0, 148.0, 71.0),
#  (133.0, 141.0, 80.0),
#  (139.0, 145.0, 46.0),
#  (116.0, 134.0, 47.0),
#  (129.0, 154.0, 58.0),
#  (127.0, 137.0, 58.0),
#  (138.0, 119.0, 24.0),
#  (114.0, 137.0, 47.0),
#  (134.0, 126.0, 26.0),
#  (136.0, 127.0, 73.0),
#  (108.0, 135.0, 64.0),
#  (140.0, 159.0, 51.0),
#  (125.0, 122.0, 28.0),
#  (111.0, 149.0, 48.0),
#  (131.0, 162.0, 68.0),
#  (107.0, 137.0, 66.0),
#  (130.0, 130.0, 57.0),
#  (125.0, 150.0, 79.0),
#  (119.0, 138.0, 40.0),
#  (152.0, 148.0, 86.0),
#  (129.0, 120.0, 33.0),
#  (121.0, 135.0, 73.0),
#  (127.0, 130.0, 55.0),
#  (129.0, 135.0, 33.0),
#  (112.0, 140.0, 60.0),
#  (133.0, 144.0, 76.0),
#  (128.0, 137.0, 93.0),
#  (135.0, 130.0, 31.0),
#  (123.0, 135.0, 79.0),
#  (127.0, 119.0, 24.0),
#  (135.0, 140.0, 82.0),
#  (124.0, 125.0, 19.0),
#  (122.0, 136.0, 55.0),
#  (136.0, 147.0, 83.0),
#  (111.0, 142.0, 53.0),
#  (139.0, 129.0, 65.0),
#  (145.0, 158.0, 73.0),
#  (142.0, 142.0, 89.0),
#  (113.0, 148.0, 57.0),
#  (119.0, 143.0, 47.0),
#  (132.0, 133.0, 58.0),
#  (135.0, 135.0, 88.0),
#  (125.0, 137.0, 93.0),
#  (118.0, 136.0, 39.0),
#  (127.0, 145.0, 97.0),
#  (131.0, 128.0, 50.0),
#  (136.0, 136.0, 41.0),
#  (148.0, 153.0, 66.0),
#  (129.0, 160.0, 70.0),
#  (105.0, 155.0, 68.0),
#  (122.0, 143.0, 50.0),
#  (141.0, 143.0, 99.0),
#  (145.0, 154.0, 61.0),
#  (110.0, 151.0, 75.0),
#  (119.0, 154.0, 77.0),
#  (125.0, 128.0, 89.0),
#  (121.0, 133.0, 61.0),
#  (127.0, 140.0, 87.0),
#  (134.0, 117.0, 8.0),
#  (128.0, 139.0, 73.0),
#  (123.0, 141.0, 65.0),
#  (135.0, 154.0, 68.0),
#  (120.0, 134.0, 53.0),
#  (114.0, 138.0, 52.0),
#  (136.0, 131.0, 44.0),
#  (136.0, 124.0, 62.0),
#  (137.0, 131.0, 67.0),
#  (117.0, 143.0, 100.0),
#  (135.0, 118.0, 27.0),
#  (128.0, 124.0, 5.0),
#  (115.0, 150.0, 45.0),
#  (145.0, 156.0, 61.0),
#  (130.0, 135.0, 40.0),
#  (129.0, 156.0, 65.0),
#  (142.0, 140.0, 77.0),
#  (128.0, 132.0, 65.0),
#  (133.0, 124.0, 11.0),
#  (121.0, 130.0, 56.0),
#  (127.0, 129.0, 28.0),
#  (122.0, 161.0, 64.0),
#  (127.0, 120.0, 10.0),
#  (118.0, 142.0, 87.0),
#  (133.0, 147.0, 59.0),
#  (137.0, 138.0, 83.0),
#  (120.0, 129.0, 48.0),
#  (114.0, 145.0, 41.0),
#  (127.0, 147.0, 85.0),
#  (148.0, 151.0, 76.0),
#  (117.0, 136.0, 95.0),
#  (108.0, 143.0, 90.0),
#  (115.0, 147.0, 42.0),
#  (119.0, 128.0, 87.0),
#  (145.0, 153.0, 58.0),
#  (130.0, 138.0, 35.0),
#  (134.0, 165.0, 62.0),
#  (113.0, 151.0, 46.0),
#  (120.0, 164.0, 63.0),
#  (144.0, 154.0, 50.0),
#  (126.0, 123.0, 9.0),
#  (127.0, 154.0, 65.0),
#  (116.0, 163.0, 59.0),
#  (141.0, 132.0, 67.0),
#  (117.0, 159.0, 71.0),
#  (123.0, 143.0, 53.0),
#  (135.0, 148.0, 56.0),
#  (137.0, 149.0, 73.0),
#  (122.0, 128.0, 45.0),
#  (111.0, 134.0, 47.0),
#  (121.0, 156.0, 58.0),
#  (139.0, 137.0, 75.0),
#  (142.0, 134.0, 67.0),
#  (128.0, 148.0, 44.0),
#  (126.0, 160.0, 66.0),
#  (138.0, 127.0, 59.0),
#  (123.0, 134.0, 97.0),
#  (131.0, 134.0, 89.0),
#  (119.0, 161.0, 54.0),
#  (143.0, 153.0, 52.0),
#  (137.0, 136.0, 99.0),
#  (123.0, 136.0, 48.0),
#  (135.0, 153.0, 51.0),
#  (120.0, 131.0, 92.0),
#  (139.0, 124.0, 58.0),
#  (136.0, 128.0, 35.0),
#  (128.0, 119.0, 29.0),
#  (136.0, 121.0, 43.0),
#  (117.0, 130.0, 85.0),
#  (122.0, 135.0, 40.0),
#  ...}

# %%
define_region_from_parcellation_to_solver('CTX_RH_G_TEMP_SUP-LATERAL', labeled_im)
ctx_rh = get_singleton_element_from_frozenset(region_solver.symbol_table['CTX_RH_G_TEMP_SUP-LATERAL'].value)
eigs = np.linalg.eigvals(ctx_rh.affine)[:-1]
resolution = abs(eigs) / 2
print(eigs)
wdt = ctx_rh.width

cant = (wdt // resolution).astype(int)
lb, ub = ctx_rh.bounding_box.lb, ctx_rh.bounding_box.ub
lsp_x = np.linspace(lb[0], ub[0], cant[0])
lsp_y = np.linspace(lb[1], ub[1], cant[1])
lsp_z = np.linspace(lb[2], ub[2], cant[2])

[px, py, pz] = np.meshgrid(lsp_x, lsp_y, lsp_z)
points = np.vstack(map(np.ravel, np.meshgrid(lsp_x, lsp_y, lsp_z)))
points.shape
print(92*198*140, len(ctx_rh.to_xyz()))
# Out:
# [-0.69999999  0.69999999  0.69999999]
# 2550240 21921

# %%
brain_stem = region_from_symbol_name(region_solver,'BRAIN-STEM')
region_solver.symbol_table[nl.Symbol[region_solver.type]('SPHERE')] = nl.Constant[AbstractSet[region_solver.type]](frozenset([sr]))
obtained = query_relation_region(region_solver, 'overlapping', 'SPHERE')
print(len(obtained), obtained)


ov_1 =  cardinal_relation(brain_stem, sr, 'O', refine_overlapping=False)
i = 6
ov_2 = cardinal_relation(brain_stem, sr, 'O', refine_overlapping=True, stop_at=i)
'after {} levels of refinement the overlapping changed from {} to {}'.format(i, ov_1, ov_2)
# Out:
# 1 ['BRAIN-STEM']
# 'after 6 levels of refinement the overlapping changed from True to True'

# %% [markdown]
# ### Example case for  union of regions

# %%
define_region_from_parcellation_to_solver('CTX_RH_G_FRONT_MIDDLE', labeled_im)
define_region_from_parcellation_to_solver('CTX_RH_S_FRONT_INF', labeled_im)
define_region_from_parcellation_to_solver('CTX_RH_S_PRECENTRAL-INF-PART', labeled_im)

r1 = region_from_symbol_name(region_solver,'CTX_RH_G_FRONT_MIDDLE')
r2 = region_from_symbol_name(region_solver,'CTX_RH_S_FRONT_INF')
r3 = region_from_symbol_name(region_solver,'CTX_RH_S_PRECENTRAL-INF-PART')
fs = set().union([r1, r2, r3])
union = region_union(fs, labeled_im.affine)

plotting.plot_roi(r1.spatial_image(), t1w_im) 
plotting.plot_roi(r2.spatial_image(), t1w_im) 
plotting.plot_roi(r3.spatial_image(), t1w_im) 
plotting.plot_roi(union.spatial_image(), t1w_im, cut_coords=[39, 27, 32])

# %% [markdown]
# ### Brain stem and sphere difference

# %%
sphere = region_from_symbol_name(region_solver,'SPHERE')
brain_stem = region_from_symbol_name(region_solver,'BRAIN-STEM')
fs = set().union([brain_stem, sphere])
diff = region_difference(fs, t1w_im.affine)
diff
#plotting.plot_roi(diff.spatial_image(), t1w_im, cut_coords=[39, 27, 32])
# Out:
# Region(VBR= affine:[[  -0.69999999    0.            0.           90.        ]
#  [   0.            0.69999999    0.         -126.        ]
#  [   0.            0.            0.69999999  -72.        ]
#  [   0.            0.            0.            1.        ]], voxels:[[131 116  19]
#  [116 147  56]
#  [144 146  81]
#  ...
#  [129 115  17]
#  [128 142  53]
#  [140 159  70]])

# %%
# d1 = region_difference([brain_stem, sphere], t1w_im.affine)
# d2 = region_difference([sphere, brain_stem], t1w_im.affine)
# union = region_union([brain_stem, sphere], t1w_im.affine)
# i1 = region_difference([union, d1, d2], t1w_im.affine)
# i2 = region_intersection([sphere, brain_stem], t1w_im.affine)


# plotting.plot_roi(d1.to_ijk(t1w_im.affine).spatial_image(), t1w_im, cut_coords=[1, -28, -43]) 
# plotting.plot_roi(d2.spatial_image(), t1w_im, cut_coords=[1, -28, -43]) 
# plotting.plot_roi(i2.spatial_image(), t1w_im, cut_coords=[1, -28, -43])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f466adbe902b> in <module>()
#       6
#       7
# ----> 8 plotting.plot_roi(d1.to_ijk(t1w_im.affine).spatial_image(), t1w_im, cut_coords=[1, -28, -43])
#       9 plotting.plot_roi(d2.spatial_image(), t1w_im, cut_coords=[1, -28, -43])
#      10 plotting.plot_roi(i2.spatial_image(), t1w_im, cut_coords=[1, -28, -43])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'spatial_image'

# %%
define_region_from_parcellation_to_solver('CTX_LH_G_TEMP_SUP-G_T_TRANSV')
define_region_from_parcellation_to_solver('CTX_LH_G_TEMP_SUP-LATERAL')
define_region_from_parcellation_to_solver('CTX_LH_G_TEMP_SUP-PLAN_POLAR')
define_region_from_parcellation_to_solver('CTX_LH_G_TEMP_SUP-PLAN_TEMPO')


ant_transv_superior_temporal =  region_from_symbol_name(region_solver,'CTX_LH_G_TEMP_SUP-G_T_TRANSV')
lat_superior_temporal = region_from_symbol_name(region_solver,'CTX_LH_G_TEMP_SUP-LATERAL')
planum_polare_superior_temporal =  region_from_symbol_name(region_solver,'CTX_LH_G_TEMP_SUP-PLAN_POLAR')
temp_plane_superior_temporal = region_from_symbol_name(region_solver,'CTX_LH_G_TEMP_SUP-PLAN_TEMPO')

fs = set().union([ant_transv_superior_temporal, lat_superior_temporal, planum_polare_superior_temporal, temp_plane_superior_temporal])
union = region_union(fs, t1w_im.affine)
plotting.plot_roi(union.spatial_image(), t1w_im)

# %%
# superior_temporal = region_from_label(region_solver, 'CTX_RH_S_TEMPORAL_SUP')
# obtained = region_solver.query_relation_region('overlapping', 'CTX_RH_S_TEMPORAL_SUP', 'rh_ovrelap_limit_temp_sup')
# rh_overlap_limit_temp_sup =  region_from_label(region_solver, 'rh_ovrelap_limit_temp_sup')
# fs = set().union([superior_temporal, rh_overlap_limit_temp_sup])
# union = region_union(fs, t1w_im.affine)
# plot_masked_region_from_voxels(t1w_im, union.to_ijk(t1w_im.affine))

# %%
region_from_plane = PlanarVolume(origin=(0,0,0), vector=(1,0,0), limit=10)
over_plane_voxels = region_from_plane.to_ijk(t1w_im.affine)
over_plane_voxels
# plotting.plot_roi(i2.spatial_image(), t1w_im, cut_coords=[1, -28, -43]) 
# plot_masked_region_from_voxels(t1w_im, over_plane_voxels, cut_coords=[1, 0, 0])
# Out:
# array([[114, 165,  88],
#        [114, 165,  89],
#        [114, 165,  90],
#        ...,
#        [127, 193, 114],
#        [127, 193, 115],
#        [127, 193, 116]])

# %%
plane_args = {'origin': (0,0,0), 'vector': (1,0,0), 'limit': 100}
pdv = get_singleton_element_from_frozenset(query_from_plane(region_solver, 'inferior_from_plane', plane_args, store_into='plane_region'))
from_plane_voxels = pdv.to_ijk(t1w_im.affine)
from_plane_voxels
plotting.plot_roi(pdv.to_explicit_vbr(affine=t1w_im.affine).spatial_image(), t1w_im) 

#plot_masked_region_from_voxels(t1w_im, from_plane_voxels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-c480aad7a776> in <module>()
#       3 from_plane_voxels = pdv.to_ijk(t1w_im.affine)
#       4 from_plane_voxels
# ----> 5 plotting.plot_roi(pdv.to_explicit_vbr(affine=t1w_im.affine).spatial_image(), t1w_im)
#       6
#       7 #plot_masked_region_from_voxels(t1w_im, from_plane_voxels)
#
# ~/Documents/python/repos/matischmit/NeuroLang/neurolang/regions.py in spatial_image(self, out, value)
#     184             mask = out.get_data()
#     185
# --> 186         mask[tuple(self._voxels.T)] = value
#     187         return out
#     188
#
# IndexError: too many indices for array

# %%
# angular_g = region_from_label(region_solver, 'CTX_RH_G_PARIET_INF-ANGULAR')
# supramarginal_g =  region_from_label(region_solver, 'CTX_RH_G_PARIET_INF-SUPRAMAR')
# temporal_plane_sup_temporal_g = region_from_label(region_solver, 'CTX_RH_G_TEMP_SUP-PLAN_TEMPO')
# posterior_ramus_lateral_s = region_from_label(region_solver, 'CTX_RH_LAT_FIS-POST')
# intermedius_primus_s = region_from_label(region_solver, 'CTX_RH_S_INTERM_PRIM-JENSEN')
# fs = set().union([angular_g, supramarginal_g, temporal_plane_sup_temporal_g, posterior_ramus_lateral_s, intermedius_primus_s])
# rois = region_union(fs, t1w_im.affine)
# plot_masked_region_from_voxels(t1w_im, rois.to_ijk(t1w_im.affine))

# %%
# roi_sr = SphericalVolume(union.center, 10)
# plotting.plot_roi(roi_sr.to_ijk(t1w_im.affine).spatial_image(), t1w_im) 
# region_solver.symbol_table[nl.Symbol[region_solver.type]('ROI-SPH')] = nl.Constant[AbstractSet[region_solver.type]](frozenset([roi_sr]))
# obtained = region_solver.query_relation_region('overlapping', 'ROI-SPH')
# print(len(obtained), obtained)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-00e025b49b39> in <module>()
#       1 roi_sr = SphericalVolume(union.center, 10)
# ----> 2 plotting.plot_roi(roi_sr.to_ijk(t1w_im.affine).spatial_image(), t1w_im)
#       3 region_solver.symbol_table[nl.Symbol[region_solver.type]('ROI-SPH')] = nl.Constant[AbstractSet[region_solver.type]](frozenset([roi_sr]))
#       4 obtained = region_solver.query_relation_region('overlapping', 'ROI-SPH')
#       5 print(len(obtained), obtained)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'spatial_image'

# %% [markdown]
# ### Using the Neurosynth API to define regions

# %%
neurosynth_im = nib.load('/home/mschmit/Documents/python/emotion/pAgF_z_FDR_0.01.nii.gz')
region_voxels = neurosynth_im.get_data().nonzero()
print(neurosynth_im)

# %%
roi_voxels = np.array(list(zip(*(region_voxels))))
ns_emotion_region = ExplicitVBR(roi_voxels, t1w_im.affine)
plotting.plot_roi(roi_sr.to_ijk(ns_emotion_region.spatial_image(), t1w_im) 
#plot_masked_region_from_voxels(neurosynth_im, roi_voxels)
len(ns_emotion_region.voxels)

# %%
# Core functionality for managing and accessing data
from neurosynth import Dataset
# Analysis tools for meta-analysis, image decoding, and coactivation analysis
from neurosynth import meta, decode, network

dataset = Dataset.load('../neurolang/utils/neurosynth/dataset.pkl')   # Note the capital D in the second Dataset--load() is a class method
ids = dataset.get_studies(features='parietal lobe', frequency_threshold=0.05)
ma = meta.MetaAnalysis(dataset, ids, q=0.01, prior=0.5)
data = ma.images['pAgF_z_FDR_0.01']
affine = dataset.masker.get_header().get_sform() #affine

# %%
brain_map = dataset.masker.unmask(data)

from scipy.ndimage import label, generate_binary_structure
s = generate_binary_structure(3,1)
labeled_array, num_features = label(brain_map, structure=s)

# %%
emotion_regions = []
for i in range(num_features):
    voxels = list(zip(*np.where(labeled_array == i)))
    emotion_regions.append(ExplicitVBR(voxels,affine))

# %%
dataset.masker.unmask(data)[12,:,:].shape

# %%
emotion_regions = sorted(emotion_regions, key= lambda x: len(x.voxels), reverse=True)

# %%
define_region_from_parcellation_to_solver('CTX_RH_S_FRONT_MIDDLE')
temporal_region = region_solver.load_term_defined_regions('temporal lobe', k=2)
next(iter(temporal_region)).bounding_box

# %%
obtained = region_solver.query_relation_region('anterior_of', 'TEMPORAL LOBE')
print(len(obtained), obtained)
