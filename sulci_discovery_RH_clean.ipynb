# %%
import matplotlib
# %matplotlib inline
from nilearn import datasets
from nilearn import plotting
import nibabel as nib

from neurolang import frontend as fe

destrieux_dataset = datasets.fetch_atlas_destrieux_2009()
destrieux_map = nib.load(destrieux_dataset['maps'])
# Out:
# /home/amachlou/miniconda3/envs/antonia/lib/python3.6/site-packages/numpy/lib/npyio.py:2278: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)

# %%
destrieux_dataset['labels']
# Out:
# rec.array([(  0, b'Background'), (  1, b'L G_and_S_frontomargin'),
#            (  2, b'L G_and_S_occipital_inf'),
#            (  3, b'L G_and_S_paracentral'),
#            (  4, b'L G_and_S_subcentral'),
#            (  5, b'L G_and_S_transv_frontopol'),
#            (  6, b'L G_and_S_cingul-Ant'),
#            (  7, b'L G_and_S_cingul-Mid-Ant'),
#            (  8, b'L G_and_S_cingul-Mid-Post'),
#            (  9, b'L G_cingul-Post-dorsal'),
#            ( 10, b'L G_cingul-Post-ventral'), ( 11, b'L G_cuneus'),
#            ( 12, b'L G_front_inf-Opercular'),
#            ( 13, b'L G_front_inf-Orbital'),
#            ( 14, b'L G_front_inf-Triangul'), ( 15, b'L G_front_middle'),
#            ( 16, b'L G_front_sup'), ( 17, b'L G_Ins_lg_and_S_cent_ins'),
#            ( 18, b'L G_insular_short'), ( 19, b'L G_occipital_middle'),
#            ( 20, b'L G_occipital_sup'), ( 21, b'L G_oc-temp_lat-fusifor'),
#            ( 22, b'L G_oc-temp_med-Lingual'),
#            ( 23, b'L G_oc-temp_med-Parahip'), ( 24, b'L G_orbital'),
#            ( 25, b'L G_pariet_inf-Angular'),
#            ( 26, b'L G_pariet_inf-Supramar'), ( 27, b'L G_parietal_sup'),
#            ( 28, b'L G_postcentral'), ( 29, b'L G_precentral'),
#            ( 30, b'L G_precuneus'), ( 31, b'L G_rectus'),
#            ( 32, b'L G_subcallosal'), ( 33, b'L G_temp_sup-G_T_transv'),
#            ( 34, b'L G_temp_sup-Lateral'),
#            ( 35, b'L G_temp_sup-Plan_polar'),
#            ( 36, b'L G_temp_sup-Plan_tempo'), ( 37, b'L G_temporal_inf'),
#            ( 38, b'L G_temporal_middle'),
#            ( 39, b'L Lat_Fis-ant-Horizont'),
#            ( 40, b'L Lat_Fis-ant-Vertical'), ( 41, b'L Lat_Fis-post'),
#            ( 42, b'L Medial_wall'), ( 43, b'L Pole_occipital'),
#            ( 44, b'L Pole_temporal'), ( 45, b'L S_calcarine'),
#            ( 46, b'L S_central'), ( 47, b'L S_cingul-Marginalis'),
#            ( 48, b'L S_circular_insula_ant'),
#            ( 49, b'L S_circular_insula_inf'),
#            ( 50, b'L S_circular_insula_sup'),
#            ( 51, b'L S_collat_transv_ant'),
#            ( 52, b'L S_collat_transv_post'), ( 53, b'L S_front_inf'),
#            ( 54, b'L S_front_middle'), ( 55, b'L S_front_sup'),
#            ( 56, b'L S_interm_prim-Jensen'),
#            ( 57, b'L S_intrapariet_and_P_trans'),
#            ( 58, b'L S_oc_middle_and_Lunatus'),
#            ( 59, b'L S_oc_sup_and_transversal'),
#            ( 60, b'L S_occipital_ant'), ( 61, b'L S_oc-temp_lat'),
#            ( 62, b'L S_oc-temp_med_and_Lingual'),
#            ( 63, b'L S_orbital_lateral'),
#            ( 64, b'L S_orbital_med-olfact'),
#            ( 65, b'L S_orbital-H_Shaped'),
#            ( 66, b'L S_parieto_occipital'), ( 67, b'L S_pericallosal'),
#            ( 68, b'L S_postcentral'), ( 69, b'L S_precentral-inf-part'),
#            ( 70, b'L S_precentral-sup-part'), ( 71, b'L S_suborbital'),
#            ( 72, b'L S_subparietal'), ( 73, b'L S_temporal_inf'),
#            ( 74, b'L S_temporal_sup'), ( 75, b'L S_temporal_transverse'),
#            ( 76, b'R G_and_S_frontomargin'),
#            ( 77, b'R G_and_S_occipital_inf'),
#            ( 78, b'R G_and_S_paracentral'),
#            ( 79, b'R G_and_S_subcentral'),
#            ( 80, b'R G_and_S_transv_frontopol'),
#            ( 81, b'R G_and_S_cingul-Ant'),
#            ( 82, b'R G_and_S_cingul-Mid-Ant'),
#            ( 83, b'R G_and_S_cingul-Mid-Post'),
#            ( 84, b'R G_cingul-Post-dorsal'),
#            ( 85, b'R G_cingul-Post-ventral'), ( 86, b'R G_cuneus'),
#            ( 87, b'R G_front_inf-Opercular'),
#            ( 88, b'R G_front_inf-Orbital'),
#            ( 89, b'R G_front_inf-Triangul'), ( 90, b'R G_front_middle'),
#            ( 91, b'R G_front_sup'), ( 92, b'R G_Ins_lg_and_S_cent_ins'),
#            ( 93, b'R G_insular_short'), ( 94, b'R G_occipital_middle'),
#            ( 95, b'R G_occipital_sup'), ( 96, b'R G_oc-temp_lat-fusifor'),
#            ( 97, b'R G_oc-temp_med-Lingual'),
#            ( 98, b'R G_oc-temp_med-Parahip'), ( 99, b'R G_orbital'),
#            (100, b'R G_pariet_inf-Angular'),
#            (101, b'R G_pariet_inf-Supramar'), (102, b'R G_parietal_sup'),
#            (103, b'R G_postcentral'), (104, b'R G_precentral'),
#            (105, b'R G_precuneus'), (106, b'R G_rectus'),
#            (107, b'R G_subcallosal'), (108, b'R G_temp_sup-G_T_transv'),
#            (109, b'R G_temp_sup-Lateral'),
#            (110, b'R G_temp_sup-Plan_polar'),
#            (111, b'R G_temp_sup-Plan_tempo'), (112, b'R G_temporal_inf'),
#            (113, b'R G_temporal_middle'),
#            (114, b'R Lat_Fis-ant-Horizont'),
#            (115, b'R Lat_Fis-ant-Vertical'), (116, b'R Lat_Fis-post'),
#            (117, b'R Medial_wall'), (118, b'R Pole_occipital'),
#            (119, b'R Pole_temporal'), (120, b'R S_calcarine'),
#            (121, b'R S_central'), (122, b'R S_cingul-Marginalis'),
#            (123, b'R S_circular_insula_ant'),
#            (124, b'R S_circular_insula_inf'),
#            (125, b'R S_circular_insula_sup'),
#            (126, b'R S_collat_transv_ant'),
#            (127, b'R S_collat_transv_post'), (128, b'R S_front_inf'),
#            (129, b'R S_front_middle'), (130, b'R S_front_sup'),
#            (131, b'R S_interm_prim-Jensen'),
#            (132, b'R S_intrapariet_and_P_trans'),
#            (133, b'R S_oc_middle_and_Lunatus'),
#            (134, b'R S_oc_sup_and_transversal'),
#            (135, b'R S_occipital_ant'), (136, b'R S_oc-temp_lat'),
#            (137, b'R S_oc-temp_med_and_Lingual'),
#            (138, b'R S_orbital_lateral'),
#            (139, b'R S_orbital_med-olfact'),
#            (140, b'R S_orbital-H_Shaped'),
#            (141, b'R S_parieto_occipital'), (142, b'R S_pericallosal'),
#            (143, b'R S_postcentral'), (144, b'R S_precentral-inf-part'),
#            (145, b'R S_precentral-sup-part'), (146, b'R S_suborbital'),
#            (147, b'R S_subparietal'), (148, b'R S_temporal_inf'),
#            (149, b'R S_temporal_sup'), (150, b'R S_temporal_transverse')],
#           dtype=[('index', '<i8'), ('name', 'S27')])

# %%
#Right Hemisphere

nl = fe.RegionFrontend()
for label_number, name in destrieux_dataset['labels']:
    name = name.decode()
    if not name.startswith('R ') or ('S_' not in name and 'Lat_Fis' not in name and 'Pole' not in name):
        continue

    # Create a region object
    region = nl.create_region(destrieux_map, label=label_number)

    # Fine tune the symbol name
    name = 'R_' + name[2:].replace('-', '_')
    nl.add_region(region, result_symbol_name=name)

# %% [markdown]
# # Temporal lobe

# %% [markdown]
# ## Lateral surface

# %% [markdown]
# ## Superior temporal sulcus

# %%
# print("Looking for the Superior Temporal Sulcus")

x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_ant_Vertical)
    )
)
res = q.do()
print("Looking for the Superior Temporal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_temporal_sup'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)
        
if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Superior Temporal Sulcus
# Found
# 10 other sulci also found:

# %% [markdown]
# ## Inferior temporal sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        (nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital) & nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital)) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central)
    )
)
res = q.do()
print("Looking for the Inferior Temporal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_temporal_inf'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Inferior Temporal Sulcus
# Found
# 3 other sulci also found:

# %% [markdown]
# ## Temporal Transverse sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_interm_prim_Jensen) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Pole_temporal) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_ant_Vertical)
    )
)
res = q.do()
print("Looking for the Transverse Temporal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_temporal_transverse'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Transverse Temporal Sulcus
# Found
# 3 other sulci also found:

# %% [markdown]
# ## Lateral Occipitotemporal sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Pole_temporal) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_circular_insula_inf)
    )
)
res = q.do()
print("Looking for the Occipitotemporal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_oc_temp_lat'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Occipitotemporal Sulcus
# Found alone

# %% [markdown]
# ## Collateral sulcus: anterior part

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Pole_temporal) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Lat_Fis_post) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont)
    )
)
res = q.do()
print("Looking for the Collateral Sulcus (anterior part)")
found_sulcus=[]
target_sulcus = 'R_S_collat_transv_ant'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Collateral Sulcus (anterior part)
# Found alone

# %% [markdown]
# ## Temporal pole

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_temporal_transverse) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_orbital_H_Shaped) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont)
    )
)
res = q.do()
print("Looking for the Temporal Pole")
found_sulcus=[]
target_sulcus = 'R_Pole_temporal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Temporal Pole
# Found alone

# %% [markdown]
# ## Lateral orbital sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_front_middle) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_orbital_H_Shaped)
    )
)
res = q.do()
print("Looking for the Lateral Orbital Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_orbital_lateral'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Lateral Orbital Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Ventral surface

# %% [markdown]
# ## Collateral sulcus (posterior)
# 2 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_temporal_sup) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_oc_middle_and_Lunatus)
    )
)
res = q.do()
print("Looking for the Collateral Sulcus (posterior part)")
found_sulcus=[]
target_sulcus = 'R_S_collat_transv_post'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Collateral Sulcus (posterior part)
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_occipital_ant) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_calcarine)
    )
)
res = q.do()
print("Looking for the Collateral Sulcus (posterior part)")
found_sulcus=[]
target_sulcus = 'R_S_collat_transv_post'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Collateral Sulcus (posterior part)
# Found alone

# %% [markdown]
# ## Occipitotemporal (medial) and lingual sulci

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_temporal_inf) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_occipital_ant) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_oc_sup_and_transversal)
    )
)
res = q.do()
print("Looking for the Medial Occipitotemporal and Lingual Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_oc_temp_med_and_Lingual'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Medial Occipitotemporal and Lingual Sulcus
# Found alone

# %% [markdown]
# ## Occipital anterior sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_post) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Pole_occipital) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_collat_transv_post)
    )
)
res = q.do()
print("Looking for the Anterior Occipital Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_occipital_ant'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Anterior Occipital Sulcus
# Found alone

# %% [markdown]
# ## Occipital superior and transversal sulci

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_interm_prim_Jensen) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_subparietal) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_calcarine)
    )
)
res = q.do()
print("Looking for the Superior Occipital and Transversal sulci")
found_sulcus=[]
target_sulcus = 'R_S_oc_sup_and_transversal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Superior Occipital and Transversal sulci
# Found alone

# %% [markdown]
# ## Occipital middle and Lunate sulcus
#
# 3 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_occipital_ant) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_collat_transv_post)
    )
)
res = q.do()
print("Looking for the Middle Occipital and Lunate Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_oc_middle_and_Lunatus'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Middle Occipital and Lunate Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_collat_transv_post) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital)
    )
)
res = q.do()
print("Looking for the Middle Occipital and Lunate Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_oc_middle_and_Lunatus'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Middle Occipital and Lunate Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_collat_transv_post) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_Lat_Fis_post)
    )
)
res = q.do()
print("Looking for the Middle Occipital and Lunate Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_oc_middle_and_Lunatus'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Middle Occipital and Lunate Sulcus
# Found alone

# %% [markdown]
# ## Inferior occipital gyrus and sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_temporal_sup) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_calcarine)
    )
)
res = q.do()
print("Looking for the Inferior Occipital Gyrus and Sulcus")
found_sulcus=[]
target_sulcus = 'R_G_and_S_occipital_inf'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Inferior Occipital Gyrus and Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Occipital Pole

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_occipital_ant) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_parieto_occipital)
    )
)
res = q.do()
print("Looking for the Occipital Pole")
found_sulcus=[]
target_sulcus = 'R_Pole_occipital'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Occipital Pole
# Found
# 2 other sulci also found:

# %% [markdown]
# # Parietal lobe

# %% [markdown]
# ## Lateral surface

# %% [markdown]
# ## Intermediate Primus of Jensen
# 3 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital)
    )
)
res = q.do()
print("Looking for the Intermediate Primus of Jensen")
found_sulcus=[]
target_sulcus = 'R_S_interm_prim_Jensen'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Intermediate Primus of Jensen
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Lat_Fis_ant_Vertical) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital)
    )
)
res = q.do()
print("Looking for the Intermediate Primus of Jensen")
found_sulcus=[]
target_sulcus = 'R_S_interm_prim_Jensen'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Intermediate Primus of Jensen
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central)
    )
)
res = q.do()
print("Looking for the Intermediate Primus of Jensen")
found_sulcus=[]
target_sulcus = 'R_S_interm_prim_Jensen'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Intermediate Primus of Jensen
# Found alone

# %% [markdown]
# ## Intraparietal sulcus
# 2 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Pole_occipital)
    )
)
res = q.do()
print("Looking for the Intraparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_intrapariet_and_P_trans'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Intraparietal Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_cingul_Marginalis)
    )
)
res = q.do()
print("Looking for the Intraparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_intrapariet_and_P_trans'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Intraparietal Sulcus
# Found alone

# %% [markdown]
# ## Postcentral sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_precentral_sup_part) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital)  
    )
)
res = q.do()
print("Looking for the Postcentral Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_postcentral'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Postcentral Sulcus
# Found
# 3 other sulci also found:

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_parieto_occipital)  
    )
)
res = q.do()
print("Looking for the Postcentral Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_postcentral'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Postcentral Sulcus
# Not found

# %% [markdown]
# ## Medial surface

# %% [markdown]
# ## Subparietal sulcus
#
# 5 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Lat_Fis_post) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_postcentral)
    )
)
res = q.do()
print("Looking for the Subparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_subparietal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Subparietal Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_intrapariet_and_P_trans) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Lat_Fis_post)
    )
)
res = q.do()
print("Looking for the Subparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_subparietal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Subparietal Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_intrapariet_and_P_trans) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont)
    )
)
res = q.do()
print("Looking for the Subparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_subparietal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Subparietal Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_temporal_sup) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_calcarine) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_postcentral)
    )
)
res = q.do()
print("Looking for the Subparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_subparietal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Subparietal Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_postcentral) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_interm_prim_Jensen)
    )
)
res = q.do()
print("Looking for the Subparietal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_subparietal'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Subparietal Sulcus
# Found alone

# %% [markdown]
# ## Marginal sulcus
# 2 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_S_precentral_sup_part) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_parieto_occipital)
    )
)
res = q.do()
print("Looking for the Marginal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_cingul_Marginalis'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Marginal Sulcus
# Found
# 2 other sulci also found:

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_G_and_S_cingul_Mid_Post) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_interm_prim_Jensen) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_G_and_S_cingul_Mid_Ant)
    )
)
res = q.do()
print("Looking for the Marginal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_cingul_Marginalis'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Marginal Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# # Frontal lobe sulci

# %% [markdown]
# ## Ventral surface
#
# --> We cannot narrow these down each specifically because we cannot differentiate between lateral/medial sulci yet

# %% [markdown]
# ## Orbital H-shaped sulcus
# 3 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Pole_temporal) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_suborbital)
    )
)
res = q.do()
print("Looking for the Orbital H-Shaped Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_orbital_H_Shaped'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Orbital H-Shaped Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Lat_Fis_ant_Vertical) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_suborbital)
    )
)
res = q.do()
print("Looking for the Orbital H-Shaped Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_orbital_H_Shaped'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Orbital H-Shaped Sulcus
# Found alone

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_precentral_inf_part) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_suborbital)
    )
)
res = q.do()
print("Looking for the Orbital H-Shaped Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_orbital_H_Shaped'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Orbital H-Shaped Sulcus
# Found alone

# %% [markdown]
# ## Olfactory sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_precentral_inf_part) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_circular_insula_ant) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_G_and_S_frontomargin)
    )
)
res = q.do()
print("Looking for the Olfactory Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_orbital_med_olfact'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Olfactory Sulcus
# Found alone

# %% [markdown]
# ## Looking for suborbital sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_orbital_H_Shaped) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_central)
    )
)
res = q.do()
print("Looking for the Suborbital Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_suborbital'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Suborbital Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Lateral surface

# %% [markdown]
# ## Looking for precentral superior and inferior parts

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont) &
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Lat_Fis_post) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal)
    )
)
res = q.do()
print("Looking for the Precentral Sulci: superior and inferior parts")
found_sulcus=[]
target_sulcus = 'R_S_precentral_sup_part' or 'R_S_precentral_inf_part'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==2:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==3:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Precentral Sulci: superior and inferior parts
# Found alone

# %% [markdown]
# ## Inferior frontal sulcus
# 2 ways.

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) #&
#         nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_precentral_sup_part)
    )
)
res = q.do()
print("Looking for the Inferior Frontal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_front_inf'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Inferior Frontal Sulcus
# Found
# 3 other sulci also found:

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_pericallosal) &
        nl.symbols.anatomical_inferior_of(x, nl.symbols.R_S_interm_prim_Jensen)
    )
)
res = q.do()
print("Looking for the Inferior Frontal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_front_inf'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Inferior Frontal Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Middle frontal sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_suborbital)
    )
)
res = q.do()
print("Looking for the Middle Frontal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_front_middle'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Middle Frontal Sulcus
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Precentral sulcus (superior part)

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_postcentral) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_front_inf) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_ant_Vertical)
    )
)
res = q.do()
print("Looking for the Precentral Sulcus (superior part)")
found_sulcus=[]
target_sulcus = 'R_S_precentral_sup_part'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Precentral Sulcus (superior part)
# Found
# 1 other sulcus also found:

# %% [markdown]
# ## Precentral sulcus (inferior part)

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_Pole_temporal) &
        nl.symbols.anatomical_posterior_of(x, nl.symbols.R_Lat_Fis_ant_Horizont)
    )
)
res = q.do()
print("Looking for the Precentral Sulcus (inferior part)")
found_sulcus=[]
target_sulcus = 'R_S_precentral_inf_part'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Precentral Sulcus (inferior part)
# Found
# 3 other sulci also found:

# %% [markdown]
# ## Superior frontal sulcus

# %%
x = nl.new_region_symbol('x')
q = nl.query(
    x, 
    (
        nl.symbols.anatomical_anterior_of(x, nl.symbols.R_S_central) &
        nl.symbols.anatomical_superior_of(x, nl.symbols.R_S_interm_prim_Jensen)
    )
)
res = q.do()
print("Looking for the Superior Frontal Sulcus")
found_sulcus=[]
target_sulcus = 'R_S_front_sup'
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
    if target_sulcus in r.symbol_name:
        found_sulcus.append(target_sulcus)

if target_sulcus in found_sulcus and len(res)==1:
    print ("Found alone")
elif target_sulcus in found_sulcus and len(res)==2:
    print("Found")
    print("1 other sulcus also found:")
elif target_sulcus in found_sulcus and len(res)!=1:
    print("Found")
    print(str(len(res)-1)+" other sulci also found:")
else:
    print("Not found")
# Out:
# Looking for the Superior Frontal Sulcus
# Found
# 1 other sulcus also found:

# %%
# -*- coding: utf-8 -*-
r'''
NeuroLang Query Example based on the Destrieux Atlas
====================================================


Uploading the Destrieux left sulci into NeuroLang and
executing some simple queries.
'''
from nilearn import datasets
from nilearn import plotting
import nibabel as nib

from neurolang import frontend as fe

###############################################################################
# Load the Destrieux example from nilearn
# ---------------------------------------

destrieux_dataset = datasets.fetch_atlas_destrieux_2009()
destrieux_map = nib.load(destrieux_dataset['maps'])

###############################################################################
# Input the left sulci into the NeuroLang interface
# -------------------------------------------------

nl = fe.RegionFrontend()
for label_number, name in destrieux_dataset['labels']:
    name = name.decode()
    if (
        not name.startswith('L ') or
        not ('S_' in name or 'Lat_Fis' in name or 'Pole' in name)
    ):
        continue

    # Create a region object
    region = nl.create_region(destrieux_map, label=label_number)

    # Fine tune the symbol name
    name = 'L_' + name[2:].replace('-', '_')
    nl.add_region(region, result_symbol_name=name.lower())

##################################################
# Plot one of the symbols

plotting.plot_roi(nl.symbols.l_s_central.value.spatial_image())


###############################################################################
# Create and run a simple query
# -----------------------------

x = nl.new_region_symbol('x')
q = nl.query(x, nl.symbols.anatomical_anterior_of(x, nl.symbols.l_s_central))
print(q)

##################################################
#

res = q.do()
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)


###############################################################################
# Create and run query which is a bit more complex
# ------------------------------------------------
x = nl.new_region_symbol('x')
q = nl.query(
    x,
    nl.symbols.anatomical_anterior_of(x, nl.symbols.l_s_central) &
    nl.symbols.anatomical_superior_of(x, nl.symbols.l_s_temporal_sup)
)
print(q)

##################################################
#

res = q.do()
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)


###############################################################################
# Create and run query with existential quantifiers and negation
# --------------------------------------------------------------
x = nl.new_region_symbol('x')
y = nl.new_region_symbol('y')
q = nl.query(
    x,
    nl.symbols.anatomical_anterior_of(x, nl.symbols.l_s_central) &
    ~nl.exists(
        y,
        nl.symbols.anatomical_anterior_of(y, nl.symbols.l_s_central) &
        nl.symbols.anatomical_anterior_of(x, y)
    )
)
print(q)

##################################################
#

res = q.do()
for r in res:
    plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)


###############################################################################
# Use the set of results from a query in a different one
# ------------------------------------------------------
x = nl.new_region_symbol('x')
temporal_lobe_query = nl.query(
    x,
    nl.symbols.anatomical_inferior_of(x, nl.symbols.l_s_parieto_occipital) &
    nl.symbols.anatomical_anterior_of(x, nl.symbols.l_s_calcarine) &
    nl.symbols.anatomical_posterior_of(x, nl.symbols.l_lat_fis_ant_vertical)
)
temporal_lobe = q.do(result_symbol_name='temporal_lobe')
print(temporal_lobe)

##################################################
#
# Out:
# /home/amachlou/miniconda3/envs/antonia/lib/python3.6/site-packages/numpy/lib/npyio.py:2278: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# {x | anatomical_anterior_of(x, l_s_central)}
# {x | ( anatomical_anterior_of(x, l_s_central) ) and_ ( anatomical_superior_of(x, l_s_temporal_sup) )}
# /home/amachlou/miniconda3/envs/antonia/lib/python3.6/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# {x | ( anatomical_anterior_of(x, l_s_central) ) and_ ( invert(∃y: ( anatomical_anterior_of(y, l_s_central) ) and_ ( anatomical_anterior_of(x, y) )) )}
# temporal_lobe: typing.AbstractSet[neurolang.regions.Region] = ['l_g_ins_lg_and_s_cent_ins', 'l_s_circular_insula_inf']

# %%
# q = nl.query(
#     x,
#     nl.symbols.temporal(x) &
#     ~nl.symbols.anatomical_inferior_of(x, nl.symbols.l_s_temporal_inf)
# )

# print(q)

# ##################################################
# #

# res = q.do()
# for r in res:
#     plotting.plot_roi(r.value.spatial_image(), title=r.symbol_name)
